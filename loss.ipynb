# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
def si_snr_loss(estimate, target, eps=1e-8):
    """
    SI-SNR loss. Always runs in FP32 — log10() on small FP16 values
    produces -inf. Inputs can be FP16; they are upcast internally.
    """
    estimate = estimate.float()
    target = target.float()

    target = target - target.mean(dim=-1, keepdim=True)
    estimate = estimate - estimate.mean(dim=-1, keepdim=True)

    alpha = (target * estimate).sum(dim=-1, keepdim=True) / \
                    (target.pow(2).sum(dim=-1, keepdim=True) + eps)
    target_scaled = alpha * target
    noise = estimate - target_scaled

    s = target_scaled.pow(2).sum(dim=-1)
    n = noise.pow(2).sum(dim=-1)
    si_snr = 10 * torch.log10((s + eps) / (n + eps))
    return -si_snr.mean()

# %%
class MultiResolutionSpectralLoss(nn.Module):
    """
    CPU STFT — fully differentiable, ultra-low VRAM (only 3 resolutions).
    Windows pinned to CPU so they never move with the model.
    """
    def __init__(self):
        super().__init__()
        self.resolutions = [(256, 64), (512, 128), (1024, 256)]   # safe for 4GB RX 560X

        for n_fft, _ in self.resolutions:
            # Create on CPU and keep it there forever
            win = torch.hann_window(n_fft, device='cpu')
            self.register_buffer(f'window_{n_fft}', win, persistent=False)

    def _stft_losses(self, x, y, n_fft, hop):
        window = getattr(self, f'window_{n_fft}').to('cpu')
        kwargs = dict(n_fft=n_fft, hop_length=hop, window=window,
                      center=False, onesided=True, return_complex=True)
        sx = torch.stft(x, **kwargs)
        sy = torch.stft(y, **kwargs)
        mag_x = sx.abs().clamp(min=1e-8)
        mag_y = sy.abs().clamp(min=1e-8)
        mag_loss = F.l1_loss(mag_x, mag_y)
        log_mag_loss = F.l1_loss(torch.log(mag_x), torch.log(mag_y))
        complex_loss = F.l1_loss(torch.view_as_real(sx),
                                  torch.view_as_real(sy))
        return mag_loss + log_mag_loss + 0.5 * complex_loss

    def forward(self, pred: torch.Tensor, targ: torch.Tensor) -> torch.Tensor:
        device = pred.device  # save DML device for final return
        
        pred_cpu = pred.squeeze(1).float().cpu()
        targ_cpu = targ.squeeze(1).float().cpu()

        # accumulate entirely on CPU — no DML transfers inside the loop
        total = torch.zeros(1, dtype=torch.float32, device='cpu')

        for n_fft, hop in self.resolutions:
            total = total + self._stft_losses(pred_cpu, targ_cpu, n_fft, hop)

        # single transfer back to DML — once per batch instead of 6 times
        return (total / len(self.resolutions)).to(device)

# %%
class GPUSpectralLoss(nn.Module):
    RESOLUTIONS = [(256, 64), (512, 128), (1024, 256)]

    def __init__(self, device=None):
        super().__init__()
        for n_fft, hop in self.RESOLUTIONS:
            conv = self._make_filterbank(n_fft, hop, device)
            self.add_module(f'fb_{n_fft}', conv)

    @staticmethod
    def _make_filterbank(n_fft: int, hop: int, device=None) -> nn.Conv1d:
        n_freqs = n_fft // 2 + 1
        t = torch.arange(n_fft, dtype=torch.float32, device=device)
        k = torch.arange(n_freqs, dtype=torch.float32, device=device)
        angles = 2 * torch.pi * k.unsqueeze(1) * t.unsqueeze(0) / n_fft
        win = 0.5 * (1 - torch.cos(2 * torch.pi * t / (n_fft - 1)))
        cos_w = (torch.cos(angles) * win).unsqueeze(1)
        sin_w = (-torch.sin(angles) * win).unsqueeze(1)
        weights = torch.cat([cos_w, sin_w], dim=0)

        conv = nn.Conv1d(1, 2 * n_freqs, n_fft, stride=hop, padding=0,
                         bias=False, device=device)
        conv.weight = nn.Parameter(weights, requires_grad=False)
        return conv

    def _magnitude(self, x: torch.Tensor, n_fft: int) -> torch.Tensor:
        fb = getattr(self, f'fb_{n_fft}')
        n_freqs = n_fft // 2 + 1
        inp = x.float().unsqueeze(1)
        out = fb(inp)
        re = out[:, :n_freqs, :]
        im = out[:, n_freqs:, :]
        return (re ** 2 + im ** 2 + 1e-8).sqrt()

    def forward(self, pred: torch.Tensor, targ: torch.Tensor) -> torch.Tensor:
        pred_2d = pred.squeeze(1)
        targ_2d = targ.squeeze(1)
        total = torch.zeros(1, dtype=torch.float32, device=pred.device)

        for n_fft, _ in self.RESOLUTIONS:
            pred_mag = self._magnitude(pred_2d, n_fft)
            targ_mag = self._magnitude(targ_2d, n_fft)
            total = total + F.l1_loss(pred_mag, targ_mag)
            total = total + F.l1_loss(torch.log(pred_mag + 1e-8),
                                      torch.log(targ_mag + 1e-8))
        return total / len(self.RESOLUTIONS)

# %%
def _envelope_loss(pred, targ, scales=[64, 256, 1024]):
    """
    Multi-scale temporal envelope loss.
    Penalizes energy at wrong times — smeared transients, wrong
    silence/speech boundaries, incorrect vowel durations.
    scales: 4ms, 16ms, 64ms windows at 16kHz.
    All ops DML-safe.
    """
    loss = torch.tensor(0.0, device=pred.device)
    for scale in scales:
        T = pred.shape[-1] // scale * scale
        p = pred[..., :T].reshape(pred.shape[0], -1, scale)
        t = targ[..., :T].reshape(targ.shape[0], -1, scale)
        p_env = p.pow(2).mean(-1).sqrt().clamp(min=1e-8)
        t_env = t.pow(2).mean(-1).sqrt().clamp(min=1e-8)
        loss = loss + F.l1_loss(torch.log(p_env), torch.log(t_env))
    return loss / len(scales)


def _temporal_gradient_loss(pred, targ):
    """
    First-order temporal derivative loss.
    Penalizes clicks, pops, musical noise artifacts.
    Catches incorrect rapid changes that waveform L1 misses.
    One subtraction + one L1 — negligible compute cost.
    """
    pred_diff = pred[..., 1:] - pred[..., :-1]
    targ_diff = targ[..., 1:] - targ[..., :-1]
    return F.l1_loss(pred_diff, targ_diff)

# %%
class CombinedLoss(nn.Module):
    """
    SI-SNR + L1 + spectral (GPU-native if required) + envelope + tgrad.

    Loss weights rationale:
      sisnr:    1.00  — primary signal, handles phase+amplitude globally
      spec:     0.40  — freq domain structure, phase via complex term
      waveform: 0.25  — time domain anchor, now meaningful
      envelope: 0.18  — temporal structure, NEW — energy timing
      tgrad:    0.08  — temporal gradient, NEW — transient artifacts
    """
    def __init__(self, debug=False, use_spectral=True):
        super().__init__()
        self.spectral = MultiResolutionSpectralLoss()
        # self.spectral = GPUSpectralLoss()
        self.debug = debug
        self.use_spectral = use_spectral

    def forward(self, pred, targ):
        pred_sq = pred.squeeze(1)
        targ_sq = targ.squeeze(1)

        sisnr = si_snr_loss(pred_sq, targ_sq)
        waveform = F.l1_loss(pred_sq.float(), targ_sq.float()) # L1
        envelope = _envelope_loss(pred_sq.float(), targ_sq.float())
        tgrad = _temporal_gradient_loss(pred_sq.float(), targ_sq.float())

        if self.use_spectral:
            spec = self.spectral(pred, targ)
            # loss = (sisnr
            #         + 0.40 * spec
            #         + 0.15 * waveform
            #         + 0.10 * envelope
            #         + 0.05 * tgrad)
            loss = (sisnr
                    + 0.40 * spec
                    + 0.25 * waveform
                    + 0.18 * envelope
                    + 0.08 * tgrad)
            if self.debug:
                print(f"  sisnr={sisnr.item():.4f} "
                      f"spec={spec.item():.4f} "
                      f"waveform={waveform.item():.4f} "
                      f"envelope={envelope.item():.4f} "
                      f"tgrad={tgrad.item():.4f}")
            return loss

        # fallback without spectral
        # return sisnr + 0.15 * waveform + 0.10 * envelope + 0.05 * tgrad
        return sisnr + 0.25 * waveform + 0.18 * envelope + 0.08 * tgrad

# %%
# class CombinedLoss(nn.Module):
#     """
#     SI-SNR + L1 + spectral (GPU-native) + power regularisation.

#     FP16 safety:
#       si_snr_loss    : upcasts to FP32 internally
#       l1_loss        : computed in FP32
#       power_reg      : on-graph FP32 (no .detach() — contributes gradients)
#       GPUSpectralLoss: upcasts pred/targ to FP32 internally, stays on GPU

#     power_reg weight = 0.05 (reduced from original 0.2 which dominated
#     the loss and suppressed SI-SNR gradient signal early in training).
#     """
#     def __init__(self, debug=False, use_spectral=True):
#         super().__init__()
#         self.spectral = MultiResolutionSpectralLoss()
#         # self.spectral = GPUSpectralLoss()
#         self.debug = debug
#         self.use_spectral = use_spectral

#     def forward(self, pred, targ):
#         pred_sq = pred.squeeze(1)
#         targ_sq = targ.squeeze(1)

#         sisnr = si_snr_loss(pred_sq, targ_sq)
#         waveform = F.l1_loss(pred_sq.float(), targ_sq.float()) # l1

#         pred_rms = pred_sq.float().pow(2).mean(dim=-1).sqrt()   # stays on DML
#         targ_rms = targ_sq.float().pow(2).mean(dim=-1).sqrt()   # stays on DML
#         log_ratio = torch.log(pred_rms.clamp(min=1e-8) / targ_rms.clamp(min=1e-8))
#         power_reg = log_ratio.pow(2).mean()

#         if self.use_spectral:
#             spec = self.spectral(pred, targ)
#             if self.debug:
#                 print(f"  sisnr={sisnr.item():.4f}  waveform={waveform.item():.4f}  "
#                       f"spec={spec.item():.4f}  power_reg={power_reg.item():.6f}")
#             return sisnr + 0.25 * spec + 0.1 * waveform + 0.05 * power_reg

#         if self.debug:
#             l1 = F.l1_loss(pred, targ) # <-- l1 shifted here
#             print(f"  sisnr={sisnr.item():.4f}  l1={l1.item():.4f}  "
#                   f"power_reg={power_reg.item():.6f}")
#         return sisnr + 0.1 * waveform + 0.05 * power_reg
