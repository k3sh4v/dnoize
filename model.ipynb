# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
import logging

# Set up a file logger with high detail
diagnostic_logger = logging.getLogger('diagnostic')
diagnostic_logger.setLevel(logging.DEBUG)
fh = logging.FileHandler('.\\training_stats\\diagnostic.log', mode='w')
fh.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(message)s')
fh.setFormatter(formatter)
diagnostic_logger.addHandler(fh)

# %%
class RMSNorm1d(nn.Module):
    """
    Drop-in replacement for nn.InstanceNorm1d on DirectML.
    Normalizes per-channel over time (same amplitude-invariance as InstanceNorm1d),
    but with proper gradient flow on DirectML hardware.

    InstanceNorm:  (x - μ) / alpha  * gamma + beta  => zero-mean, unit-variance
    RMSNorm1d:     x / RMS(x) * gamma + beta        -> unit-RMS, ~unit-variance when μ≈0

    For audio (approximately zero-mean), the difference is negligible.
    Input / output shape: (B, C, T) - identical to InstanceNorm1d.
    """
    def __init__(self, num_channels, eps=1e-4, affine=True, device=None):
        super().__init__()
        self.eps = eps
        self.affine = affine
        if affine:
            # Shape (1, C, 1) broadcasts over (B, C, T) - same as InstanceNorm1d
            # Create directly on the target device instead of defaulting to CPU
            self.weight = nn.Parameter(torch.ones(1, num_channels, 1, device=device))
            self.bias   = nn.Parameter(torch.zeros(1, num_channels, 1, device=device))

    def forward(self, x):
        # x: (B, C, T)
        # RMS per (B, C) over T - same normalization axis as InstanceNorm1d

        rms = torch.sqrt(torch.mean(x ** 2, dim=-1, keepdim=True) + self.eps)

        rms = torch.clamp(rms, min=1e-4)  # enforce minimum RMS
        x = x / rms
        if self.affine:
            x = x * self.weight + self.bias
        return x

# %%
class CausalConv1d(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride=1,
                 dilation=1, groups=1, bias=True, device=None):
        super().__init__()
        self.conv = nn.Conv1d(
            in_channels, out_channels, kernel_size,
            stride=stride, dilation=dilation,
            groups=groups, bias=bias, device=device
        )
        self.pad_len        = (kernel_size - 1) * dilation
        self._pad_cache     = None
        self._pad_cache_key = None

    def _get_pad(self, x):
        key = (x.shape[0], x.shape[1], self.pad_len, x.dtype)
        if self._pad_cache is None or self._pad_cache_key != key:
            self._pad_cache     = torch.zeros(
                x.shape[0], x.shape[1], self.pad_len,
                dtype=x.dtype, device=x.device
            )
            self._pad_cache_key = key
        return self._pad_cache

    def forward(self, x):
        if self.pad_len > 0:
            x = torch.cat([self._get_pad(x), x], dim=-1)
        return self.conv(x)

# %%
# class CausalOutputProj(nn.Module):
#     """
#     Final 1×3 causal projection channels->1, computed on CPU.
    
#     Conv1d bias/weight gradient reduction over T=96000 has ~1% error
#     on DirectML due to parallel reduction order differences vs CPU.
#     This layer sees the largest gradient signal (closest to loss) so
#     the error accumulates most here.
    
#     Moving to CPU costs one device transfer per forward/backward but
#     the tensor is (B, C, T) float32 = 2*64*40000*4 = 20.5MB - acceptable.
#     """
#     def __init__(self, channels, device=None):
#         super().__init__()
#         # always created on CPU regardless of device= arg
#         self.proj = nn.Conv1d(channels, 1, kernel_size=3, bias=False)
#         self.pad_len = 2   # kernel_size - 1, for causal padding
#         self._pad_cache     = None
#         self._pad_cache_key = None

#     def _get_pad(self, x):
#         key = (x.shape[0], x.shape[1], self.pad_len, x.dtype)
#         if self._pad_cache is None or self._pad_cache_key != key:
#             self._pad_cache     = torch.zeros(
#                 x.shape[0], x.shape[1], self.pad_len,
#                 dtype=x.dtype, device=torch.device('cpu')
#             )
#             self._pad_cache_key = key
#         return self._pad_cache

#     def forward(self, x):
#         dev = x.device
#         x_cpu = x.cpu()
#         if self.pad_len > 0:
#             x_cpu = torch.cat([self._get_pad(x_cpu), x_cpu], dim=-1)
#         # ensure proj is on CPU - fastai's .to(device) may have moved it
#         if self.proj.weight.device.type != 'cpu':
#             self.proj.to(torch.device('cpu'))
#         out = self.proj(x_cpu)
#         return out.to(dev)

class CausalOutputProj(nn.Module):
    def __init__(self, channels, device=None):
        super().__init__()
        self.proj = nn.Conv1d(channels, 1, kernel_size=3, bias=False, device=device)
        self.pad_len = 2   # kernel_size - 1, for causal padding
        self._pad_cache     = None
        self._pad_cache_key = None

    def _get_pad(self, x):
        # print(f"device of x in _get_pad: {x.device}")
        # x = x.cpu()
        key = (x.shape[0], x.shape[1], self.pad_len, x.dtype)
        if self._pad_cache is None or self._pad_cache_key != key:
            self._pad_cache = torch.zeros(
                x.shape[0], x.shape[1], self.pad_len,
                dtype=x.dtype, device=x.device
            )
            self._pad_cache_key = key
        return self._pad_cache


    def forward(self, x):
        # Get current epoch for logging
        current_epoch = EPOCH_SEED.value  # set by set_epoch_seed() before each epoch [2]

        x_padded = x
        if self.pad_len > 0:
            x_padded = torch.cat([self._get_pad(x), x], dim=-1)

        out = self.proj(x_padded)

        # Check input for NaN
        input_has_nan = torch.isnan(x).any().item()
        input_has_inf = torch.isinf(x).any().item()
        if input_has_nan or input_has_inf:
            diagnostic_logger.info(
                f"[Epoch {current_epoch}] [CausalOutputProj] Input NaN={input_has_nan}, Inf={input_has_inf} "
                f"| input device={x.device}, weight device={self.proj.weight.device}"
            )

        # Check output for NaN
        output_has_nan = torch.isnan(out).any().item()
        output_has_inf = torch.isinf(out).any().item()
        if output_has_nan or output_has_inf:
            diagnostic_logger.info(
                f"[Epoch {current_epoch}] [CausalOutputProj] Output NaN={output_has_nan}, Inf={output_has_inf} "
                f"| output device={out.device}, weight device={self.proj.weight.device}"
            )

        # Register gradient hook that logs only when NaN gradient appears
        # The hook captures the current epoch via closure
        def nan_grad_hook(grad, epoch=current_epoch):
            grad_nan = torch.isnan(grad).any().item()
            grad_inf = torch.isinf(grad).any().item()
            if grad_nan or grad_inf:
                diagnostic_logger.info(
                    f"[Epoch {epoch}] [CausalOutputProj grad hook] "
                    f"NaN={grad_nan}, Inf={grad_inf} | grad norm: {grad.norm():.6f}"
                )
            return grad

        if out.requires_grad:
            out.register_hook(nan_grad_hook)

        return out


    # def hook_logger(grad):
    #     diagnostic_logger.info(
    #         f"[grad hook] out grad norm: {grad.norm():.6f}, "
    #         f"NaN={torch.isnan(grad).any().item()}, "
    #         f"Inf={torch.isinf(grad).any().item()}"
    #     )

    #     return grad

    # def forward(self, x):
    #     x_padded = x
    #     if self.pad_len > 0:
    #         x_padded = torch.cat([self._get_pad(x), x], dim=-1)

    #     # Diagnostic: device checks
    #     diagnostic_logger.info("\n\n\n")
    #     diagnostic_logger.info(f"[CausalOutputProj] input device: {x.device}, weight device: {self.proj.weight.device}")
    #     diagnostic_logger.info(f"[CausalOutputProj] input has NaN: {torch.isnan(x).any().item()}, Inf: {torch.isinf(x).any().item()}")

    #     out = self.proj(x_padded)

    #     # print(out.grad_fn.name.__dir__())

    #     # Diagnostic: output checks
    #     diagnostic_logger.info(f"[CausalOutputProj] output device: {out.device}")
    #     diagnostic_logger.info(f"[CausalOutputProj] output has NaN: {torch.isnan(out).any().item()}, Inf: {torch.isinf(out).any().item()}")

    #     if hasattr(out, 'grad_fn'):
    #         if out.grad_fn is not None:
    #             diagnostic_logger.info(f"[CausalOutputProj] output grad_fn: {out.grad_fn.name.__repr__()}")  # None if detached

    #             # Gradient hook to catch NaN in backward
    #             out.register_hook(hook_logger)
    #     return out

# %%
class CausalUpsample(nn.Module):
    """
    Causal upsample by factor 2 using interleaved channel split.

    repeat_interleave backward is broken on DirectML (confirmed: 6.29e-01
    gradient diff at dec.3.conv.bias in Section 4).
    ConvTranspose1d(groups=channels) is also broken on DirectML
    (RuntimeError: The parameter is incorrect).

    This implementation splits channels into 2 halves and interleaves them
    in the time dimension - equivalent to 1D pixel shuffle. Uses only
    reshape + permute + contiguous, all of which are supported on DirectML.

    Input:  (B, C, T)
    Output: (B, C, T*2)  - causal, no future frames used
    """
    def __init__(self, channels=None, device=None):
        super().__init__()
        # learned mixing before the shuffle so the model can control
        # how it distributes information across the two interleaved positions
        self.mix = nn.Conv1d(channels, channels * 2, 1, bias=False, device=device)
        nn.init.xavier_uniform_(self.mix.weight, gain=1.0)

    def forward(self, x):
        # x: (B, C, T)
        B, C, T = x.shape
        # mix to 2C channels - one set for even positions, one for odd
        h = self.mix(x)                    # (B, 2C, T)
        # reshape to (B, C, T, 2) then interleave along time axis
        h = h.view(B, C, 2, T)            # (B, C, 2, T)
        h = h.permute(0, 1, 3, 2)         # (B, C, T, 2)
        h = h.reshape(B, C, T * 2)        # (B, C, T*2) - interleaved
        return h

# %%
class CausalDNoizeBlock(nn.Module):
    """Causal depthwise-separable block with InstanceNorm and GLU gating"""
    def __init__(self, channels=96, kernel=3, dilation=1, device=None):
        super().__init__()
        self.dw = CausalConv1d(channels, channels, kernel, groups=channels,
                                dilation=dilation, bias=False, device=device)
        # GLU: double channels, split into content + gate
        self.pw = nn.Conv1d(channels, channels * 2, 1, bias=False, device=device)
        self.norm = RMSNorm1d(channels, eps=1e-4, affine=True, device=device)

    def forward(self, x):
        residual = x
        out = self.dw(x)
        out = self.pw(out)
        content, gate = out.chunk(2, dim=1)
        out = content * torch.sigmoid(gate)
        out = self.norm(out)
        if out.shape[-1] != residual.shape[-1]:
            out = out[..., :residual.shape[-1]]
        return out + residual

# %%
class CausalDNoizeConvTasNet(nn.Module):
    """
    Ultra-fast CPU inference speech enhancement
    Params: ~230k
    MACs/sec @16kHz: ~25-45M (faster than GTCRN)
    """

    def __init__(self, channels=48, num_blocks=9, num_repeats=2, kernel=3, device=None):
        super().__init__()

        # Encoder - stride 2 downsampling
        self.enc = CausalConv1d(1, channels, kernel_size=5, stride=2, device=device)
        self.norm_enc = RMSNorm1d(channels, eps=1e-4, affine=True, device=device)
        self.act_enc = nn.ReLU()

        # Processing blocks
        self.blocks = nn.Sequential(*[
            CausalDNoizeBlock(channels, kernel, dilation=2**(i % num_blocks), device=device)
            for i in range(num_repeats * num_blocks)
        ])

        # Bottleneck mask head
        self.mask_head = nn.Sequential(
            nn.Conv1d(channels, channels * 2, 1, device=device),
            nn.ReLU(),
            nn.Conv1d(channels * 2, channels, 1, device=device)
        )

        self.dec = nn.Sequential(
            CausalUpsample(channels=channels, device=device),
            CausalConv1d(channels, channels, kernel_size=5, stride=1, device=device),
            nn.ReLU(),
        )

        # self.out_proj = CausalOutputProj(channels, device=torch.device('cpu'))
        self.out_proj = CausalOutputProj(channels, device=device)

        self._init_weights()

    def _init_weights(self):
        # -- General init for all Conv1d and RMSNorm1d ------------------
        for m in self.modules():
            if isinstance(m, nn.Conv1d):
                nn.init.xavier_uniform_(m.weight)
            elif isinstance(m, (nn.InstanceNorm1d, RMSNorm1d)):  # <- ADD RMSNorm1d
                if hasattr(m, 'weight') and m.weight is not None:
                    nn.init.constant_(m.weight, 1.0)
                if hasattr(m, 'bias') and m.bias is not None:
                    nn.init.constant_(m.bias, 0.0)
            elif isinstance(m, nn.ConvTranspose1d):
                nn.init.xavier_uniform_(m.weight)
            elif isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                if m.bias is not None:
                    nn.init.zeros_(m.bias)

        # -- mask_head --------------------------------------------------------
        # Zero weight init -> all outputs = 0 -> ReLU dead from step 1
        # -> mask_head receives no gradients (confirmed in S3/S6 of debug script).
        # Small nonzero weights let ReLU activate, sigmoid(small) ≈ 0.5 which
        # is still a neutral mask at init.
        for m in self.mask_head.modules():
            if isinstance(m, nn.Conv1d):
                nn.init.xavier_uniform_(m.weight, gain=0.01)
                if m.bias is not None:
                    nn.init.zeros_(m.bias)
        # Nudge first conv bias positive so ReLU(x) > 0 from step 1
        nn.init.constant_(self.mask_head[0].bias, 0.01)

        # # CausalUpsample - init mix conv to xavier (already done by general loop,
        # # but restate explicitly so the intent is clear after the repeat_interleave
        # # and ConvTranspose1d removal history)
        # nn.init.xavier_uniform_(self.dec[0].mix.weight, gain=1.0)

        # decoder convs - small gain, skip CausalUpsample (index 0)
        for m in self.dec.modules():
            if isinstance(m, nn.Conv1d):
                nn.init.xavier_uniform_(m.weight, gain=0.01)
                if m.bias is not None:
                    nn.init.zeros_(m.bias)

        # out_proj lives on CPU - same small gain
        nn.init.xavier_uniform_(self.out_proj.proj.weight, gain=0.01)

        # CausalUpsample mix conv
        nn.init.xavier_uniform_(self.dec[0].mix.weight, gain=1.0)

    def forward(self, x):
        input_length = x.shape[-1]

        enc = self.enc(x)
        enc = self.norm_enc(enc)
        enc = self.act_enc(enc)

        feat = self.blocks(enc)

        mask = torch.sigmoid(self.mask_head(feat))
        masked = feat * mask

        out = self.dec(masked)
        out = self.out_proj(out)

        if out.shape[-1] > input_length:
            out = out[..., :input_length]
        elif out.shape[-1] < input_length:
            zeros = torch.zeros(*out.shape[:-1], input_length - out.shape[-1],
                                dtype=out.dtype, device=out.device)
            out = torch.cat([out, zeros], dim=-1)

        scale = OUTPUT_SCALE.value
        out = out.clamp(-1, 1) * scale
        return x + out
