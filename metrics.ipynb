# %%
import torch
import torch.nn.functional as F
from fastai.learner import Metric
import numpy as np
from pesq import pesq
from pystoi import stoi

# %%
# %run model.ipynb

# %%
def pesq_metric(pred, targ):
    """PESQ metric - computed on CPU"""
    pred = pred.squeeze(1).detach().cpu().numpy()
    targ = targ.squeeze(1).detach().cpu().numpy()
    scores = []
    for i in range(len(pred)):
        try:
            score = pesq(16000, targ[i], pred[i], 'wb')
            scores.append(score)
        except Exception as e:
            pass
    return np.mean(scores) if scores else 0.0

# %%
def stoi_metric(pred, targ):
    """STOI metric - computed on CPU"""
    pred = pred.squeeze(1).detach().cpu().numpy()
    targ = targ.squeeze(1).detach().cpu().numpy()
    scores = []
    for i in range(len(pred)):
        try:
            score = stoi(targ[i], pred[i], 16000, extended=False)
            scores.append(score)
        except Exception as e:
            scores.append(0.0)
    return np.mean(scores) if scores else 0.0

# %%
def evaluate_checkpoint(model_path, dls, channels=48, num_blocks=10, 
                        num_repeats=2, n_batches=20):
    """
    Compute PESQ and STOI on a saved model.
    Call this once after training completes, not during training.
    
    n_batches: number of validation batches to evaluate (set to None for all)
    """
    model = CausalDNoizeConvTasNet(
        channels=channels, 
        num_blocks=num_blocks,
        num_repeats=num_repeats 
    )
    
    import warnings
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        state = torch.load(model_path, map_location='cpu', weights_only=False)
    
    # SaveModelCallback saves full learner state, not just model state_dict
    # Handle both formats
    if 'model' in state:
        model.load_state_dict(state['model'])
    else:
        model.load_state_dict(state)
    
    model.eval()

    pesq_scores, stoi_scores = [], []

    for batch_idx, (xb, yb) in enumerate(dls.valid):
        if n_batches and batch_idx >= n_batches:
            break

        xb_cpu = xb.float().cpu()
        yb_cpu = yb.float().cpu()

        with torch.no_grad():
            pred = model(xb_cpu)

        pred_np = pred.squeeze(1).numpy()
        targ_np = yb_cpu.squeeze(1).numpy()

        for i in range(len(pred_np)):
            try:
                pesq_scores.append(pesq(16000, targ_np[i], pred_np[i], 'wb'))
            except:
                pass
            try:
                stoi_scores.append(stoi(targ_np[i], pred_np[i], 16000, extended=False))
            except:
                pass

    pesq_mean = np.mean(pesq_scores) if pesq_scores else 0.0
    stoi_mean = np.mean(stoi_scores) if stoi_scores else 0.0
    print(f"PESQ : {pesq_mean:.4f} (target > 2.5)")
    print(f"STOI : {stoi_mean:.4f} (target > 0.88)")
    return pesq_mean, stoi_mean

# %%
class SISNRMetric(Metric):
    """
    Positive SI-SNR in dB (higher is better).
    Computed entirely on device tensors - no CPU/RAM overhead.
    
    Target values:
        epoch  0: ~-12 to -8 dB   (worse than noisy input)
        epoch 32: ~-8 dB          (where you actually are - confirmed)
        epoch 100: ~0 to +5 dB    (breaking even with noisy input)
        epoch 200: ~+8 to +12 dB  (good result for this model size)
    """
    def reset(self):
        self.total = torch.tensor(0.0)
        self.count = 0

    def accumulate(self, learn):
        pred = learn.pred.squeeze(1).detach().float().cpu()
        targ = learn.yb[0].squeeze(1).detach().float().cpu()

        targ_zm = targ - targ.mean(dim=-1, keepdim=True)
        pred_zm = pred - pred.mean(dim=-1, keepdim=True)

        eps = 1e-8
        alpha = (targ_zm * pred_zm).sum(-1, keepdim=True) / \
                (targ_zm.pow(2).sum(-1, keepdim=True) + eps)
        s = (alpha * targ_zm).pow(2).sum(-1)
        n = (pred_zm - alpha * targ_zm).pow(2).sum(-1)
        sisnr = 10 * torch.log10((s + eps) / (n + eps))

        self.total += sisnr.sum().cpu()
        self.count += pred.shape[0]

    @property
    def value(self):
        return (self.total / self.count).item() if self.count > 0 else None

    @property
    def name(self):
        return "sisnr_db"

# %%
class NoiseReductionPct(Metric):
    """
    Percentage of noise power removed.
    Negative = model is making audio worse than noisy input.
    Expected to be negative early in training, crossing 0 around epoch 15-25.
    """
    def reset(self):
        self.total = torch.tensor(0.0)
        self.count = 0

    def accumulate(self, learn):
        noisy = learn.xb[0].squeeze(1).detach().float().cpu()
        clean = learn.yb[0].squeeze(1).detach().float().cpu()
        pred  = learn.pred.squeeze(1).detach().float().cpu()

        original_noise_pwr  = (noisy - clean).pow(2).mean(-1)
        remaining_noise_pwr = (pred  - clean).pow(2).mean(-1)

        # clamp(-100, 100) not (0, 100) - show negative values
        pct = ((original_noise_pwr - remaining_noise_pwr) /
               (original_noise_pwr + 1e-8) * 100).clamp(-100, 100)

        self.total += pct.sum().cpu()
        self.count += pred.shape[0]

    @property
    def value(self):
        return (self.total / self.count).item() if self.count > 0 else None

    @property
    def name(self):
        return "noise_removed_%"

# %%
class SDRImprovement(Metric):
    """SDR improvement over noisy input. Target: >5 dB ep100, >10 dB ep200."""
    def reset(self): self.total = 0.0; self.count = 0

    def accumulate(self, learn):
        noisy = learn.xb[0].squeeze(1).detach().float().cpu()
        clean = learn.yb[0].squeeze(1).detach().float().cpu()
        pred  = learn.pred.squeeze(1).detach().float().cpu()
        eps   = 1e-8
        def sdr(est, ref):
            return 10 * torch.log10(
                ref.pow(2).sum(-1) / ((est-ref).pow(2).sum(-1) + eps) + eps)
        self.total += (sdr(pred, clean) - sdr(noisy, clean)).clamp(-30,30).sum().item()
        self.count += pred.shape[0]

    @property
    def value(self): return self.total/self.count if self.count else None
    @property
    def name(self): return "sdr_improvement_db"

# %%
class SegSNRImprovement(Metric):
    """Segmental SNR improvement. Proxy for CBAK. Target: >8 dB ep100."""
    def reset(self): self.total = 0.0; self.count = 0

    def accumulate(self, learn):
        pred  = learn.pred.squeeze(1).detach().float().cpu()
        clean = learn.yb[0].squeeze(1).detach().float().cpu()
        noisy = learn.xb[0].squeeze(1).detach().float().cpu()
        frame, eps = 320, 1e-8
        T = pred.shape[-1] // frame * frame
        def seg_snr(est, ref):
            e = est[...,:T].reshape(est.shape[0],-1,frame)
            r = ref[...,:T].reshape(ref.shape[0],-1,frame)
            return (10*torch.log10(
                r.pow(2).mean(-1)/(( e-r).pow(2).mean(-1)+eps)+eps
            )).clamp(-10,35).mean(-1)
        self.total += (seg_snr(pred,clean) - seg_snr(noisy,clean)).sum().item()
        self.count += pred.shape[0]

    @property
    def value(self): return self.total/self.count if self.count else None
    @property
    def name(self): return "seg_snr_improvement_db"

# %%
class LogSpectralDistance(Metric):
    """
    Log Spectral Distance - lower is better.
    Measures average spectral distortion in dB per frame.
    Realistic targets: <8 dB by epoch 100, <4 dB at convergence.
    Computed on CPU - avoids DirectML STFT issues.
    """
    def __init__(self):
        super().__init__()
        self._window = torch.hann_window(512, device='cpu')
        self.stft_kwargs = {
            "n_fft": 512, "hop_length": 128, "window": self._window,
            "return_complex": True, "center": False, "onesided": True
        }

    def reset(self):
        self.total = 0.0
        self.count = 0

    def _power_spec(self, x):
        # recreate window fresh to avoid any device issues
        return torch.stft(
            x, **self.stft_kwargs
        ).abs().pow(2).clamp(min=1e-8)

    def accumulate(self, learn):
        pred  = learn.pred.squeeze(1).detach().float().cpu()
        clean = learn.yb[0].squeeze(1).detach().float().cpu()

        for i in range(pred.shape[0]):
            p_pred  = self._power_spec(pred[i])   # (freq, time)
            p_clean = self._power_spec(clean[i])   # (freq, time)

            # LSD: sqrt of mean squared log spectral diff per frame,
            # then averaged over frames
            log_diff = 10 * (torch.log10(p_clean) - torch.log10(p_pred))
            per_frame = torch.sqrt(log_diff.pow(2).mean(0))  # mean over freq
            lsd = per_frame.mean()                            # mean over time
            self.total += lsd.item()
            self.count += 1

    @property
    def value(self): return self.total / self.count if self.count else None
    @property
    def name(self): return "log_spectral_dist"

# %%
class LSDOptimalGain(Metric):
    """
    Log Spectral Distance after removing the best constant gain offset.
    Measures pure spectral SHAPE distortion - ignores overall level mismatch.

    Compare with LogSpectralDistance (scale-sensitive):
      - If LSDOptimalGain << LogSpectralDistance:
            model has a level problem - investigate waveform L1 weight
      - If LSDOptimalGain ≈ LogSpectralDistance:
            model level is correct - spectral shape is the issue

    Lower is better. Target: < 4 dB at convergence.
    Computed on CPU - avoids DirectML STFT issues.
    """

    def __init__(self):
        super().__init__()
        self.n_fft=512
        self._window = torch.hann_window(self.n_fft, device='cpu')  # created once
        self.stft_kwargs = {
            "n_fft": self.n_fft, "hop_length": 128, "window": self._window,
            "return_complex": True, "center": False, "onesided": True
        }

    def reset(self):
        self.total = 0.0
        self.count = 0

    def _power_spec(self, x: torch.Tensor) -> torch.Tensor:
        """Returns power spectrum (freq, time), clamped for log safety."""
        return torch.stft(
            x, **self.stft_kwargs
        ).abs().pow(2).clamp(min=1e-8)

    def accumulate(self, learn):
        pred  = learn.pred.squeeze(1).detach().float().cpu()
        clean = learn.yb[0].squeeze(1).detach().float().cpu()

        for i in range(pred.shape[0]):
            p_pred  = self._power_spec(pred[i])   # (freq, time)
            p_clean = self._power_spec(clean[i])   # (freq, time)

            log_pred  = torch.log10(p_pred)
            log_clean = torch.log10(p_clean)

            # best constant gain offset in dB (least-squares on log scale)
            # removes the single global level difference between pred and clean
            gain = log_clean.mean() - log_pred.mean()

            # LSD after correcting for gain
            log_diff  = log_clean - (log_pred + gain)
            per_frame = torch.sqrt(log_diff.pow(2).mean(dim=0))  # RMS over freq
            lsd       = per_frame.mean()                          # mean over time

            self.total += lsd.item()
            self.count += 1

    @property
    def value(self):
        return self.total / self.count if self.count > 0 else None

    @property
    def name(self):
        return "lsd_optimal_gain"
